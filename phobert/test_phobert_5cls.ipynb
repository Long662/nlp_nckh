# %%
import numpy as np
import torch
from pathlib import Path
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Module textproc nằm cùng thư mục với notebook
from textproc import (
    LABELS_5, normalize_text, maybe_segment, sentiment_prefix,
    approx_diacritic_ratio, restore_diacritics
)

ID2LBL = {i: l for i, l in enumerate(LABELS_5)}

# ==== Cấu hình cơ bản ====
MODEL_DIR = str((Path("../phobert_5cls_clean")).resolve())

# 'cuda' nếu có GPU, không thì dùng 'cpu'
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

MAX_LEN = 160
USE_SEG = False          # bật nếu bạn train có segmentation
NORMALIZE = True
AUTO_RESTORE = True
RESTORE_THRESHOLD = 0.03
NEUTRAL_PENALTY = 0.0    # penalty cho 'neutral' (index 2)
USE_PREFIX = True        # bật để khớp lúc train
CPU_THREADS = 0          # 0 = mặc định PyTorch, >0 để giới hạn thread

# %%
# ==== Load tokenizer + model ====
if DEVICE == "cuda" and not torch.cuda.is_available():
    raise RuntimeError("DEVICE được đặt là 'cuda' nhưng CUDA không khả dụng.")

device = torch.device(DEVICE)

if device.type == "cpu" and CPU_THREADS > 0:
    torch.set_num_threads(CPU_THREADS)

# Luôn nạp model float32, nếu chạy CPU thì ép map về CPU
load_kwargs = dict(torch_dtype=torch.float32, low_cpu_mem_usage=True)
if device.type == "cpu":
    load_kwargs["device_map"] = {"": "cpu"}

tok = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=False)
mdl = AutoModelForSequenceClassification.from_pretrained(
    MODEL_DIR, **load_kwargs
).to(device).eval()

print("Loaded model from:", MODEL_DIR)
print("Device:", device)
print("Labels:", LABELS_5)
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 5571.05it/s]
# Loaded model from: D:\HK252\TTNT\phobert_5cls_clean
# Device: cpu
# Labels: ['very_negative', 'negative', 'neutral', 'positive', 'very_positive']

# %%
def softmax_np(x):
    x = x - np.max(x, keepdims=True)
    e = np.exp(x)
    return e / np.sum(e, keepdims=True)

def preprocess_text(raw: str) -> str:
    """Tiền xử lý giống script CLI."""
    s = normalize_text(raw) if NORMALIZE else raw

    # Auto restore dấu nếu tỷ lệ dấu < threshold
    if AUTO_RESTORE and approx_diacritic_ratio(s) < RESTORE_THRESHOLD:
        restored = restore_diacritics(s)
        print(f'[INFO] Auto-restore diacritics → "{restored}"')
        s = restored

    # Prefix cảm xúc (giống lúc train)
    if USE_PREFIX:
        s = sentiment_prefix(s, max_tag=1)

    # Word segmentation (nếu dùng)
    s = maybe_segment(s, use_seg=USE_SEG)
    return s

def predict_one(text: str):
    """Trả về (nhãn, độ tin cậy, vector xác suất)."""
    mdl.eval()
    s = preprocess_text(text)

    with torch.inference_mode():
        enc = tok([s], truncation=True, padding=True,
                  max_length=MAX_LEN, return_tensors="pt")
        enc = {k: v.to(device) for k, v in enc.items()}
        logits = mdl(**enc).logits
        logits = logits.detach().cpu().numpy()[0]

    # (tuỳ chọn) chỉnh neutral
    if NEUTRAL_PENALTY != 0.0:
        logits[2] += NEUTRAL_PENALTY  # 'neutral' index 2

    probs = softmax_np(logits)
    pred_id = int(probs.argmax())
    pred_lbl = ID2LBL[pred_id]
    return pred_lbl, float(probs[pred_id]), probs

def pretty_print(text: str):
    pred_lbl, conf, probs = predict_one(text)
    print("=" * 60)
    print("Text:", text)
    print("Pred:", pred_lbl)
    print("Conf:", f"{conf:.6f}")
    print("Probs:")
    for i, name in enumerate(LABELS_5):
        print(f"  {name:15s}: {float(probs[i]):.6f}")

# %%
# ==== Test nhanh với một vài câu mẫu ====
samples = [
    "máy ảnh nét, màu sắc ổn định, rất ưng",
    "giao hàng chậm, sản phẩm trầy xước",
    "Mình thấy laptop bình thường",
    "Sản phẩm tạm ổn",
    "ok",
    "đồ ăn dở tệ, sẽ không mua lại"
]

for s in samples:
    pretty_print(s)
# Out:
# ============================================================
# Text: máy ảnh nét, màu sắc ổn định, rất ưng
# Pred: very_positive
# Conf: 0.812259
# Probs:
#   very_negative  : 0.052970
#   negative       : 0.047652
#   neutral        : 0.023813
#   positive       : 0.063307
#   very_positive  : 0.812259
# ============================================================
# Text: giao hàng chậm, sản phẩm trầy xước
# Pred: very_negative
# Conf: 0.969927
# Probs:
#   very_negative  : 0.969927
#   negative       : 0.009377
#   neutral        : 0.006347
#   positive       : 0.011308
#   very_positive  : 0.003041
# ============================================================
# Text: Mình thấy laptop bình thường
# Pred: neutral
# Conf: 0.926823
# Probs:
#   very_negative  : 0.024378
#   negative       : 0.023493
#   neutral        : 0.926823
#   positive       : 0.020453
#   very_positive  : 0.004854
# ============================================================
# Text: Sản phẩm tạm ổn
# Pred: neutral
# Conf: 0.904046
# Probs:
#   very_negative  : 0.030565
#   negative       : 0.023497
#   neutral        : 0.904046
#   positive       : 0.036010
#   very_positive  : 0.005881
# ============================================================
# Text: ok
# Pred: positive
# Conf: 0.929101
# Probs:
#   very_negative  : 0.015837
#   negative       : 0.013567
#   neutral        : 0.008228
#   positive       : 0.929101
#   very_positive  : 0.033267
# ============================================================
# Text: đồ ăn dở tệ, sẽ không mua lại
# Pred: very_negative
# Conf: 0.601322
# Probs:
#   very_negative  : 0.601322
#   negative       : 0.367779
#   neutral        : 0.011629
#   positive       : 0.013306
#   very_positive  : 0.005964

# %%
# ==== Nhập tay để test ====
# Chạy cell này, sau đó gõ câu trên terminal Jupyter / VSCode.
# Bấm Enter rỗng để thoát.

# while True:
#     try:
#         text = input("Nhập câu (Enter rỗng để thoát): ").strip()
#     except EOFError:
#         break
#     if not text:
#         break
#     pretty_print(text)

# %%
import csv
from pathlib import Path

CSV_PATH = Path("../data/test/test.csv")

def eval_on_csv(csv_path=CSV_PATH, max_rows=None):
    """
    Đọc file CSV có cột 'text' và 'label',
    chạy model và in ra dự đoán + tính accuracy.
    """
    golds = []
    preds = []

    with csv_path.open("r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for i, row in enumerate(reader):
            if max_rows is not None and i >= max_rows:
                break

            text = row["text"]
            gold = row["label"].strip()

            pred_lbl, conf, probs = predict_one(text)

            golds.append(gold)
            preds.append(pred_lbl)

            # In kết quả từng dòng (có thể bỏ bớt nếu quá dài)
            print("=" * 80)
            print(f"Row {i+1}")
            print("Text :", text)
            print("Gold :", gold)
            print("Pred :", pred_lbl)
            print("Conf :", f"{conf:.6f}")

    # Tính accuracy đơn giản
    correct = sum(g == p for g, p in zip(golds, preds))
    total = len(golds)
    acc = correct / total if total > 0 else 0.0

    print("\n" + "#" * 80)
    print(f"Done. Samples: {total}")
    print(f"Accuracy: {acc:.4f} ({correct}/{total})")

    # (tuỳ chọn) đếm theo từng label
    from collections import Counter
    print("\nGold label counts:", Counter(golds))
    print("Pred label counts:", Counter(preds))

# Gọi hàm để chạy trên toàn bộ file
eval_on_csv()
# Out:
# ================================================================================
# Row 1
# Text : Shop làm ăn ko đúng giao hàng sai ko đúng như sản phẩm cần mua. Củ sạc 4 lỗ nhưng giao 2 lỗ. Mất uy tín
# Gold : very_negative
# Pred : very_negative
# Conf : 0.957202
# ================================================================================
# Row 2
# Text : "3 viên vệ sinh máy, năm in trên bao bì là 2020, vì bất đồng ngôn ngữ nên ko rõ được ngày sản xuất hay ngày hết hạn. Nhưng bây giờ là 2022 rồi, nên thất vọng vì cách làm ăn của shop!"
# Gold : very_negative
# Pred : very_negative
# Conf : 0.803916
# ================================================================================
# Row 3
# Text : Mình thấy dien thoai không đáng tiền, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.940638
# ================================================================================
# Row 4
# Text : Chất liệu:nỉ. Màu sắc:đen. Đúng với mô tả:ko nha. . Lúc đầu mình ko nghe được máy của ship per , lúc đấy rất buồn ạ . May mà shipper còn gọi r mới lấy được hàng , vì bản thân mình rất ghét kiểu người hay bom hàng á . Nên bản thân đã mua thì phải lấy . Áo nó mỏng như gì luôn á trời , thấy hơi buồn nha . Thui bữa sau chả dám đặt nữa ạ ...😌
# Gold : very_negative
# Pred : very_negative
# Conf : 0.326930
# ================================================================================
# Row 5
# Text : Vai ò shop ko kiểm tra đồ trước khi giao cho khách à, mở ra có luôn vết bửn
# Gold : negative
# Pred : negative
# Conf : 0.930217
# ================================================================================
# Row 6
# Text : Hàng ko đúng mẫu, cũ, trầy
# Gold : negative
# Pred : negative
# Conf : 0.730158
# ================================================================================
# Row 7
# Text : chuot cũng bt thôi, giá hợp lý.
# Gold : neutral
# Pred : neutral
# Conf : 0.929307
# ================================================================================
# Row 8
# Text : Nhận máy hộp đả mở..k đúng như mới..y như hàng đả sử dụng rồi. Thất vọng. Mày chạy yếu nhớt .k như quảng cáo...hộp hình như đả có người mỡ rồi..k vui chút nào...tui mua hàng ở shopeee rầt nhuều nhưng cái này thất vọng. K uy tín
# Gold : very_negative
# Pred : very_negative
# Conf : 0.971239
# ================================================================================
# Row 9
# Text : robot hut bui hỏng ngay lần 1, giao hàng lâu.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.970288
# ================================================================================
# Row 10
# Text : Mình thấy chuot không đáng tiền, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.932932
# ================================================================================
# Row 11
# Text : Giao hàng nhanh.Gói hàng kĩ thẻ nhìn ok ghi dc 5p là bị ngắt k kết nối được..định dạng thẻ lại được 5p lại bị tiếp
# Gold : very_negative
# Pred : very_negative
# Conf : 0.924241
# ================================================================================
# Row 12
# Text : rõ ràng đặt hàng là có thể sạc h thành phải cắm nó mới chạy đóng hàng kiểu j tệ z thậm chí xước tùm lum
# Gold : very_negative
# Pred : very_negative
# Conf : 0.954965
# ================================================================================
# Row 13
# Text : Shop giao hàng đúng hẹn, đóng gói sơ sài. củ sạc nhìn chắc chắn nhưng chỉ là sạc bình thường, không phải củ sạc nhanh
# Gold : neutral
# Pred : neutral
# Conf : 0.543730
# ================================================================================
# Row 14
# Text : laptop siêu thất vọng, giao hàng kẹt mãi.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969269
# ================================================================================
# Row 15
# Text : 3 bộ đồ chơi mà shop giao có 2 cục bin. Thiếu 4 cục bin. Hộp đựng đồ chơi còn bị tháo bung ra
# Gold : very_negative
# Pred : very_negative
# Conf : 0.535221
# ================================================================================
# Row 16
# Text : Chất lượng phù hợp giá tiền, giao nhanh, khá hài lòng nhưng khi ráp mới phát hiện thiếu ốc ... bỏ ốc vô hộp lại ko có túi đựng riêng làm ốc rớt ghim cả vào ván gỡ mãi mới ra, xong kiểm lại thì bị thiếu.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.748210
# ================================================================================
# Row 17
# Text : Giao hàng nhanh ,shop tv nhiet tinh đúng mẫu chua sd chua biet...nhưng hơi that vong hop móp méo ..ship giao hk coi dc nen hoi bun ti
# Gold : very_negative
# Pred : very_negative
# Conf : 0.671832
# ================================================================================
# Row 18
# Text : Mua chung 1 đống đồ dùng con gái mà cho 1 cái mùi khg thể nào Men hơn chữ Men trên chai:)). Đã Men rồi còn Coast là mùi tui ghét nữa chứ. Nhìn hình cứ nghĩ mùi nữ. Rồi giờ ai xài, khui ra cái xịt keo cứng người
# Gold : very_negative
# Pred : very_negative
# Conf : 0.467669
# ================================================================================
# Row 19
# Text : Ko lên nguồn vậy chết rồi
# Gold : negative
# Pred : negative
# Conf : 0.635669
# ================================================================================
# Row 20
# Text : "Giao hàng đúng hẹn, 1 viên không làm sạch máy rửa chén như chai vệ sinh máy."
# Gold : neutral
# Pred : neutral
# Conf : 0.766226
# ================================================================================
# Row 21
# Text : "Nhận sản phẩm mà thật sự tức giận. Vải thì mỏng dánh. Màu trắng thì đen thui, dính màu vào. Sản phẩm này mà giặt chỉ có vứt vào thùng rác vì màu đen lem vào màu trắng. Đề nghị tiki xem lại các nhà phân phối hợp tác. Làm sao để đổi trả lại vì sản phẩm lem màu"
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969445
# ================================================================================
# Row 22
# Text : "Túi đểu. Ko phải da thật, lởm lắm."
# Gold : very_negative
# Pred : negative
# Conf : 0.843583
# ================================================================================
# Row 23
# Text : Sách dở… đừng mua… viết luyên thuyên
# Gold : very_negative
# Pred : very_negative
# Conf : 0.953135
# ================================================================================
# Row 24
# Text : Hình thức tệ: sp ko có hộp hay tem dán niêm phong gì cả; không thấy nsx nhưng hsd đến tận tháng 11/2028(ít nhất 4 năm) trong khi thông thường các sp sữa rửa mặt hay mỹ phẩm khác sẽ có hsd dưới 3 năm, rất lo ngại về chất lượng, nghi vấn hàng giả
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969575
# ================================================================================
# Row 25
# Text : Cx thơm nhưng mùa xịt ko hơi bị hắc một tí
# Gold : neutral
# Pred : positive
# Conf : 0.763546
# ================================================================================
# Row 26
# Text : RẤT TỆ về mặt sản phẩm là 2/10 còn cách tiếp xúc với khách hàng của shop rất tệ âm vô cùng điểm , trả lời khách hàng thấp kém thô lỗ máy thì dỏm đừng nên mua
# Gold : very_negative
# Pred : very_negative
# Conf : 0.940886
# ================================================================================
# Row 27
# Text : Chê, fom xấu; hàng QT mà đóng gói ẩu thế này, thất vọng
# Gold : very_negative
# Pred : very_negative
# Conf : 0.946759
# ================================================================================
# Row 28
# Text : "hàng nhận được không phải như đặt, chất lượng không xác định được, bao gói không đúng như là hàng giả, không có chữ hướng dẫn nào bằng tiếng anh."
# Gold : very_negative
# Pred : very_negative
# Conf : 0.964225
# ================================================================================
# Row 29
# Text : Quá tệ.linh kiện bên trong nó thay hết. Vỏ sau lưng mất luôn ốc r. Trầy xước lung tung luôn. lag vs đơ cực kì. cài windows còn k được
# Gold : very_negative
# Pred : very_negative
# Conf : 0.971887
# ================================================================================
# Row 30
# Text : "giao đúng hẹn, đóng gói cẩn thận"
# Gold : positive
# Pred : positive
# Conf : 0.959190
# ================================================================================
# Row 31
# Text : Phát khùng với cái nồi ạ. Bộ đinh ốc đi theo cái nắp nồi không phải cùng bộ với cái nồi . Vặn vào rất chật, xộc xệch và lọc cọc. Con ốc to nên ko có cố ráng vặn vào cái lỗ trên miếng nhựa đc ,nhựa rất giòn sợ gãy. 2 cái miếng để cố định con ốc thì quá nhỏ so với cái lỗ khoét trên nắp. Lọc cọc không có tác dụng gì cả. Cố xài chắc chịu đựng lọc cọc nhấc lên xuống 10 lần là gãy luôn. Rất không hài lòng cái nắp nên e muốn trả lại . Còn nồi 3lit này thì trông to hơn tưởng tượng, chất liệu nhìn tốt và cứng cáp. Mong cho e trả sản phẩm. Gần nửa triệu cho khoảng 10 lần sử dụng thì thôi ạ !
# Gold : very_negative
# Pred : very_negative
# Conf : 0.908072
# ================================================================================
# Row 32
# Text : Không phải hàng chính hãng nên phần đầu làm bằng nhựa bóng, không mờ như hàng chính hãng. Thấy kéo cũng khá êm. Phần cán gia công tạm ổn. Nói chung tiền nào của đó.
# Gold : neutral
# Pred : positive
# Conf : 0.518054
# ================================================================================
# Row 33
# Text : Chất liệu không giống tưởng tượng, khá mỏng, nhưng mà giá như thế này thì tam, chỉ là họa tiết không giống hình lắm
# Gold : very_negative
# Pred : very_negative
# Conf : 0.836458
# ================================================================================
# Row 34
# Text : Sạc để 65w mà máy 44w sạc không nhanh được shop, dây sạc lúc ăn lúc không
# Gold : very_negative
# Pred : very_negative
# Conf : 0.518955
# ================================================================================
# Row 35
# Text : Cây mắt xã dùng cũng tạm được
# Gold : neutral
# Pred : neutral
# Conf : 0.923801
# ================================================================================
# Row 36
# Text : Sản phẩm KHông dùng đc như quảng cáo, nhờ tư vân hỗ trợ thì trả lời chậm chạp , rồi cu4nh ko giúp đc gì, trả lời như cái máy. coi như mất tiền...
# Gold : very_negative
# Pred : very_negative
# Conf : 0.967438
# ================================================================================
# Row 37
# Text : Giang hàng nhanh.đóng gói ẩu tả thất vọng về shop..
# Gold : very_negative
# Pred : very_negative
# Conf : 0.936463
# ================================================================================
# Row 38
# Text : Sau vài lần dải nằm thì em nó bị tút sợi bông lại như thế.và sợi bông ko mềm mại lại còn dặm dát lưng nữa.thật tệ cho màu sản phẩm đẹp.
# Gold : negative
# Pred : negative
# Conf : 0.716339
# ================================================================================
# Row 39
# Text : Đèn ổn, dao dài ổn👍. 1 trong bốn cái bị tách phần kẹp và phần dao ra
# Gold : neutral
# Pred : positive
# Conf : 0.887460
# ================================================================================
# Row 40
# Text : tai nghe tạm dc, giá ko quá cao.
# Gold : neutral
# Pred : neutral
# Conf : 0.926819
# ================================================================================
# Row 41
# Text : chuot không có gì đặc biệt, giá ko quá cao.
# Gold : neutral
# Pred : neutral
# Conf : 0.916545
# ================================================================================
# Row 42
# Text : Mình thấy dong ho pin tụt lẹ, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.960601
# ================================================================================
# Row 43
# Text : 200c là 20 bịch. nma shop giao 19 bịch!!. là uy tín dữ luôn
# Gold : very_negative
# Pred : very_negative
# Conf : 0.961640
# ================================================================================
# Row 44
# Text : Quá mỏng, bé, chất lượng tệ. Không dùng được.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.971180
# ================================================================================
# Row 45
# Text : man hinh siêu thất vọng, giao hàng delay hoài.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.967574
# ================================================================================
# Row 46
# Text : khâu chăm sóc khách hàng quá tệ hại
# Gold : very_negative
# Pred : very_negative
# Conf : 0.966672
# ================================================================================
# Row 47
# Text : Sản phẩm ok nha
# Gold : positive
# Pred : positive
# Conf : 0.912097
# ================================================================================
# Row 48
# Text : Rẻ nên thế là oce r
# Gold : positive
# Pred : positive
# Conf : 0.506908
# ================================================================================
# Row 49
# Text : Đặt ship hoả tốc mà shop trả lời 5 ngày mới có hàng! Nhắn tin làm gắt lên thì 2-3 ngày sau mới nhận đc hàng và áo bị bẩn ở vai !!!!! Từ cách cskh tới chất lượng thất sự rất tệ. Đóng gói ổn
# Gold : very_negative
# Pred : very_negative
# Conf : 0.968062
# ================================================================================
# Row 50
# Text : dong ho kinh dị luôn, giao hàng lâu.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.971206
# ================================================================================
# Row 51
# Text : dong ho tạm dc, giá ko quá cao.
# Gold : neutral
# Pred : neutral
# Conf : 0.930069
# ================================================================================
# Row 52
# Text : Yêuu cầu shop đóng kỹ hơn
# Gold : neutral
# Pred : positive
# Conf : 0.936956
# ================================================================================
# Row 53
# Text : Chất vải nóng và mỏng màu xám nhìn không được đúng màu như ảnh quảng cáo
# Gold : negative
# Pred : negative
# Conf : 0.748666
# ================================================================================
# Row 54
# Text : "Tay đòn quá ngắn, rất khó gắn vào kính chiếu hậu của xe máy"
# Gold : negative
# Pred : negative
# Conf : 0.949611
# ================================================================================
# Row 55
# Text : tai nghe siêu thất vọng, giao hàng lâu.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969580
# ================================================================================
# Row 56
# Text : Theo cá nhân mình đánh giá sách 6/10. Mình chỉ thấy một ít chỗ là hay, đáng lưu tâm. còn lại thì viết Nội dung hơi khó khăn cho người đọc, giải thích lòng vòng, ngoài ra còn viết sai chính tả khá nhiều. Đối với mình, là người mới, đang tập tành thói quen đọc sách, thì mình thấy quyển sách này không phù hợp lắm mặc dù đã cố gắng đọc tới 8 phần 10 cuốn sách rồi vẫn thấy khó thấm nội dung."
# Gold : negative
# Pred : negative
# Conf : 0.926920
# ================================================================================
# Row 57
# Text : Nhận hàng về phấn vỡ đổ quá trời dính đầy trên vỏ hộp
# Gold : very_negative
# Pred : very_negative
# Conf : 0.965352
# ================================================================================
# Row 58
# Text : Không có sổ tay hướng dẫn, không kết nối được Bluetooth, muốn liên lạc với shop để tư vấn nhưng không được, tự làm theo hướng dẫn của Window Microsoft cả chục lần nhưng vẫn không thấy biểu tượng Bluetooth
# Gold : very_negative
# Pred : very_negative
# Conf : 0.947193
# ================================================================================
# Row 59
# Text : Mình thấy laptop tạm bợ, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.964406
# ================================================================================
# Row 60
# Text : Mình tưởng là chân bắt vít sẵn cho chắc nhưng sản phẩm là dán băng keo nha
# Gold : negative
# Pred : positive
# Conf : 0.664386
# ================================================================================
# Row 61
# Text : Sản phẩm giặt ra màu. Giặt lần 3 là màu đen thành bạc và màu trắng thành màu xám
# Gold : very_negative
# Pred : negative
# Conf : 0.617809
# ================================================================================
# Row 62
# Text : Nhìn cũng được, cũng ổn
# Gold : neutral
# Pred : neutral
# Conf : 0.857144
# ================================================================================
# Row 63
# Text : robot hut bui bực mình vl, giao hàng delay hoài.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.970111
# ================================================================================
# Row 64
# Text : "Sách tốt, tuy có đóng trong bao bóng xốp nhưng chỉ có 1 lớp nên vẫn bị cọ xát và nhăn 1 chút ở gáy sách. Nên quấn thêm 1 lớp thì tốt hơn."
# Gold : positive
# Pred : positive
# Conf : 0.815157
# ================================================================================
# Row 65
# Text : chuot không nổi bật, giá tạm ổn.
# Gold : neutral
# Pred : neutral
# Conf : 0.933122
# ================================================================================
# Row 66
# Text : Âm thanh hay nghe cũng bass mạnh nhưng có điều ko nhận trả bài tiếp theo được thôi
# Gold : neutral
# Pred : neutral
# Conf : 0.612173
# ================================================================================
# Row 67
# Text : Mới nhận 3 ngày, mà cây kim bự ở ngoài cùng nó cứ lỏng tới lỏng lui phải đẩy vôngày hôm qua không để ý, nó bung luôn, k chụp kịp chắc t ăn cám rồi :))
# Gold : negative
# Pred : negative
# Conf : 0.941857
# ================================================================================
# Row 68
# Text : Sản phẩm robot hut bui ngon lành cành đào, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.964125
# ================================================================================
# Row 69
# Text : Ban đầu mình có đặt để tặng sinh nhật nhưng sau 2 ngày vẫn chưa thấy shop gửi đơn đi và đã nhắn nhờ shop hủy đơn giúp nhưng shop vẫn gửi đi. Đến nơi thì mình cũng nhận hàng, nma shop giao kh đúng màu, mình đặt màu hồng, shop giao mà trắng, nút ghi âm bị lệch qua một bên nữa. Kh biết sao luon
# Gold : very_negative
# Pred : very_negative
# Conf : 0.616722
# ================================================================================
# Row 70
# Text : "Chậm chạp, tư vấn ko nhiệt tình"
# Gold : very_negative
# Pred : very_negative
# Conf : 0.694688
# ================================================================================
# Row 71
# Text : Màu sắc:qua tệ. Đúng với mô tả:sai mua bộ gửi cái áo vớ vẩn. . Shop xử lý quá kem khi lỗi do shop gửi nhầm
# Gold : very_negative
# Pred : very_negative
# Conf : 0.970847
# ================================================================================
# Row 72
# Text : Hàng ko giống hình, chỉ là hàng face thôi , chỉ có mấy chục nghìn ko đáng phải trả hàng vì ko có thời gian, mọi người ko nên mua, hình ảnh shop đăng tôi đánh dấu đỏ, khác xa với hình nhận được , dịch vụ thì tệ
# Gold : very_negative
# Pred : very_negative
# Conf : 0.916257
# ================================================================================
# Row 73
# Text : Kẻ như SỊT đc mấy bữa là hết mực t mới quăng xuống đất đây ĐỪNG MUA NHA AE
# Gold : very_negative
# Pred : negative
# Conf : 0.835021
# ================================================================================
# Row 74
# Text : Đúng với mô tả:không đúng. . Hàng nhận được bị hỏng không sử dụng được. Liên hệ thì shop không hỗ trợ
# Gold : very_negative
# Pred : very_negative
# Conf : 0.962277
# ================================================================================
# Row 75
# Text : laptop thảm họa 😱, giao hàng kẹt mãi.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969781
# ================================================================================
# Row 76
# Text : Miễn phí sip nhưng lại thu sip .don hàng Miễn mà sop lại thu nhé. Ae cẩn thận khi nhận hàng nhé
# Gold : negative
# Pred : negative
# Conf : 0.823504
# ================================================================================
# Row 77
# Text : "Vải bị ra màu,giặt lem hết trơn"
# Gold : very_negative
# Pred : very_negative
# Conf : 0.943902
# ================================================================================
# Row 78
# Text : Đóng gói cẩn thận an toàn.. Sản phẩm có vẻ mới 99% theo đúng mô tả trên Shopee.. Keo tản nhiệt chưa test nên chưa biết chất lượng làm mát ra sao? nhưng phần đánh giá của khách hàng rất xuất sắc!. Tạm thời cho 4*, khi dùng sẽ đánh giá lại?
# Gold : positive
# Pred : positive
# Conf : 0.590474
# ================================================================================
# Row 79
# Text : Giao đúng hàng, lo nhỏ hơn mình tưởng, không rè , đúng nghĩa mini, nói cũng cũng tạm
# Gold : neutral
# Pred : neutral
# Conf : 0.718928
# ================================================================================
# Row 80
# Text : Sản phẩm robot hut bui xịn sò vl, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.966215
# ================================================================================
# Row 81
# Text : Đúng với mô tả:khác. Màu sắc:nâu cafe. Chất liệu:nhựa. . Hàng đúng mô tả và số lượng. Dép nâu chứ ko phải màu ghi. Giao hàng nhanh. Cho shop 4 sao ạ.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.789774
# ================================================================================
# Row 82
# Text : Lần 2 mua của shop, vẫn k thích kiểu đóng gói mất an toàn như này, bên vận chuyển làm vỡ cả sản phẩm (lỗi do quy trình gói hàng của shop). Đóng gói quá sơ sài, k bóng xốp chống sốc cho sản phẩm gây hư hại, đổi trả mất tg nên tạm dùng. Lần này cho 2 sao để cảnh báo shop về việc tương tự... Hy vọng shop mau chóng khắc phục cách đóng gói bảo quản sản phẩm đến tay khách hàng. Quá thái độ
# Gold : very_negative
# Pred : very_negative
# Conf : 0.621237
# ================================================================================
# Row 83
# Text : xài được 2 tháng có dấu hiệu đơ nút, dù mình xài rất bình thương, chỉ sử dụng 4-6h/ngày. Thất vọng
# Gold : very_negative
# Pred : very_negative
# Conf : 0.963210
# ================================================================================
# Row 84
# Text : như mô tả quảng cáo về sản phẩm.
# Gold : negative
# Pred : negative
# Conf : 0.531437
# ================================================================================
# Row 85
# Text : Mỏng chỉ khâu sơ sài thừa nhiều
# Gold : negative
# Pred : negative
# Conf : 0.961099
# ================================================================================
# Row 86
# Text : Hơi mỏng so với mình nghĩ , chun thì ngắn ngủn , ko cài được xuống đệm , shop giao nhanh ,
# Gold : neutral
# Pred : neutral
# Conf : 0.770188
# ================================================================================
# Row 87
# Text : Sản phẩm tai nghe best choice, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.914664
# ================================================================================
# Row 88
# Text : great, tuyệt vời!!!
# Gold : very_positive
# Pred : very_positive
# Conf : 0.778177
# ================================================================================
# Row 89
# Text : Đặt 4xl lại gửi hàng là 2xl, ntin gọi điện cho chị ý thig chị ý hẹn hết hnay lại ngày mai ship cho size mới, nma cuối cùng lại kh ship vì lý do lúc thì quên lúc thì nvien kh đến làm kh ship đc ..bla bla. Shop làm ăn quá chán
# Gold : very_negative
# Pred : very_negative
# Conf : 0.848706
# ================================================================================
# Row 90
# Text : Máy xay yếu, này mình chỉ xay sữa uống thôi á, mà lần bật lên xay được vài giây là ngắt rồi, kiểu này sao xay sinh tố trái cây gì nổi
# Gold : negative
# Pred : negative
# Conf : 0.800268
# ================================================================================
# Row 91
# Text : "Giao hàng đúng hẹn, 1 viên không làm sạch máy rửa chén như chai vệ sinh máy. Nhưng tóm lại vẫn là 1 sản phẩm tốt. Chất lượng đúng với giá tiền."
# Gold : positive
# Pred : positive
# Conf : 0.946254
# ================================================================================
# Row 92
# Text : chuot kinh dị luôn, giao hàng lâu.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969553
# ================================================================================
# Row 93
# Text : Kết cấu không đặc lắm, mùi dễ chịu, tạo bọt dễ
# Gold : very_positive
# Pred : very_positive
# Conf : 0.780202
# ================================================================================
# Row 94
# Text : Đồng hồ vẫn chạy nhưng chạy không đúng giờ .. xài ko dc ..mua phí tiền..không nên mua
# Gold : very_negative
# Pred : very_negative
# Conf : 0.971342
# ================================================================================
# Row 95
# Text : 3 cái kẹp kia thì khá ổn nma đến cái kẹp hình 🔪 thì đúng là rất tệ vì nó bị bung hết ra luôn ý
# Gold : negative
# Pred : negative
# Conf : 0.739493
# ================================================================================
# Row 96
# Text : Phấn mịn nhưng nhận về vỡ tan tành ko dùng đc j cả. Giá rẻ ko hi vọng nhiều nhưng vỡ quá nhiều
# Gold : very_negative
# Pred : very_negative
# Conf : 0.695987
# ================================================================================
# Row 97
# Text : Shop lần sau để ý 1 tí, giao cho 2 cái đều đen, chán hẳn, làm ăn kiểu này rất dễ mất khách. Chất liệu vải phù hợp với giá tiền
# Gold : negative
# Pred : negative
# Conf : 0.539989
# ================================================================================
# Row 98
# Text : Mới giặt 1 lần mà đã rách rồi in sao rất nhiều chỉ thừa khồn nên mua 1 tí nào
# Gold : very_negative
# Pred : very_negative
# Conf : 0.836628
# ================================================================================
# Row 99
# Text : Mình thấy chuot rep chậm, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.961802
# ================================================================================
# Row 100
# Text : Chỉ có 2 tốc độ sấy. Tầm giá bình dân, vậy là ổn.
# Gold : neutral
# Pred : positive
# Conf : 0.946749
# ================================================================================
# Row 101
# Text : Áo có vẻ dễ bị dãn, nhưng mức giá này thì chấp nhận. Cho 2 sao vì trên shop báo có 2 mặt hàng khuyến mãi kèm nhưng thực tế không có!
# Gold : negative
# Pred : negative
# Conf : 0.763681
# ================================================================================
# Row 102
# Text : Shop giao sản phẩm không giống mẫu đã đặt mua. Chất lượng sản phẩm không tốt.
# Gold : negative
# Pred : negative
# Conf : 0.914394
# ================================================================================
# Row 103
# Text : Sản phẩm đúng như mô tả của shop. Mới lắp, chưa thử vận hành máy nên chưa biết hiệu quả chống rung ra sao nhưng ban đầu cảm giác ổn
# Gold : positive
# Pred : positive
# Conf : 0.789618
# ================================================================================
# Row 104
# Text : Đúng với mô tả:Không đúng. Màu sắc:đen M. . Giao về áo khác mẫu kh có mũ kh đúng , hình ảnh
# Gold : very_negative
# Pred : very_negative
# Conf : 0.966747
# ================================================================================
# Row 105
# Text : Lần đầu tiên đánh giá 1* khi mua onl. Hàng vỡ mà kh nt còn lơ đi nữa. K thể chấp nhận đc
# Gold : very_negative
# Pred : very_negative
# Conf : 0.911243
# ================================================================================
# Row 106
# Text : Giao hàng nhanh đóng gói kĩ
# Gold : positive
# Pred : positive
# Conf : 0.897175
# ================================================================================
# Row 107
# Text : Sản phẩm dong ho mượt mà 10/10, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.967660
# ================================================================================
# Row 108
# Text : Bông tai đẹp, kẹp xinh, nhưng gói hàng tệ lắm luôn. . Nhồi chung 1 bịch bé tí. Kẹp tóc nơ, cột tóc nhăn nhàu hết. Ko biết xử lý sao cho nó thẳng lại cho đúng phom luôn í ạ 🥹🥹🥹 . Hy vọng lần sau shop gói hàng cẩn thận hơn để ko làm mất phom kẹp và cột.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.847750
# ================================================================================
# Row 109
# Text : Sản phẩm hết hạn sử dụng hay sao?
# Gold : negative
# Pred : negative
# Conf : 0.916509
# ================================================================================
# Row 110
# Text : rất hài lòng
# Gold : very_positive
# Pred : very_positive
# Conf : 0.611518
# ================================================================================
# Row 111
# Text : Mình thấy loa khó chịu vc, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.924746
# ================================================================================
# Row 112
# Text : Có hiệu quả giảm khô da sau khi sd.
# Gold : positive
# Pred : positive
# Conf : 0.603709
# ================================================================================
# Row 113
# Text : Đăng hình miếng trên mặc vải dù Đế bằng nhựa thì ₫úng miếng trên bằng nhựa lúc giao ko ₫úng đăng trên bán
# Gold : negative
# Pred : negative
# Conf : 0.465262
# ================================================================================
# Row 114
# Text : giá bán quá đắt. Hôm qua tình cờ vào trang chuyên sản phẩm cho máy rửa chén thì giá có 135 ngàn free ship. vậy mà mình mua tính cả phí ship là 159 ngàn. tính ra đắt hơn 26 ngàn. như vậy sản phẩm đắt hơn ngoài thị trường rất nhiều. từ nay đặt hàng ở tiki phải khảo giá trước. thất vọng
# Gold : very_negative
# Pred : very_negative
# Conf : 0.927738
# ================================================================================
# Row 115
# Text : loa tạm dc, giá tạm ổn.
# Gold : neutral
# Pred : neutral
# Conf : 0.929400
# ================================================================================
# Row 116
# Text : Mấy anh chị mua thì nên cân nhắc kỹ nha. . Đặt 4 màu giao sai cả 4 màu, quá tệ luôn nha, màu xanh lá với màu rêu là nó i chang nhau nha mọi người 🥹. Chất vải là dạng nỉ có xốp nhẹ bên trong mặt trên láng mịn nhưng cũng là vải thôi . . Cao su gì ko biết ???? Lần đâu tiên tui mới có khái niệm cao su non là zị . Tui biết xốp cao su . Tui biết nệm cao su . Nhưng cái chiếu cao su này nó thiệt là lừa người 😂😂😂tui ko trả hàng , vì tui muốn đánh giá của tui sẽ được mọi người đọc , hiểu và biết thêm về sản phẩm trước khi quyết định mua
# Gold : negative
# Pred : very_negative
# Conf : 0.761741
# ================================================================================
# Row 117
# Text : Gửi saii hàng khách nhắn tin ko trả lời của khách :)))
# Gold : very_negative
# Pred : very_negative
# Conf : 0.659772
# ================================================================================
# Row 118
# Text : loa không có gì đặc biệt, giá hợp lý.
# Gold : neutral
# Pred : neutral
# Conf : 0.932246
# ================================================================================
# Row 119
# Text : Máy tốt nhưng tôi ko thể kết nổi đc liệu có thể giúp tôi đc ko
# Gold : negative
# Pred : neutral
# Conf : 0.737622
# ================================================================================
# Row 120
# Text : Màu sắc:ko đúng màu. . Hàng ko đúng màu ko như quảng cáo
# Gold : very_negative
# Pred : very_negative
# Conf : 0.968891
# ================================================================================
# Row 121
# Text : "Rất đắng đo khi mua, nhưng về dùng thì thấy rất ổn. Dùng hết viên cuối sẽ ủng hộ tiếp !"
# Gold : very_positive
# Pred : very_positive
# Conf : 0.567500
# ================================================================================
# Row 122
# Text : Giao đến hết pin xước . Shop vận chuyển hơi chán
# Gold : very_negative
# Pred : very_negative
# Conf : 0.926206
# ================================================================================
# Row 123
# Text : Ko ra cái gì tẩy ố ko sạch
# Gold : very_negative
# Pred : very_negative
# Conf : 0.958763
# ================================================================================
# Row 124
# Text : tai nghe bực mình vl, giao hàng lâu.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.968278
# [INFO] Auto-restore diacritics → ""nap nhua de van bulong thay doi khoang cach cua giá độ moi van vao de giu dien thoai. da bi rot ra nhu hình""
# ================================================================================
# Row 125
# Text : "Nap nhua de van bulong thay doi khoang cach cua gia do moi van vao de giu Dien thoai. Da bi rot ra nhu hinh"
# Gold : negative
# Pred : very_negative
# Conf : 0.826316
# ================================================================================
# Row 126
# Text : man hinh hỏng ngay lần 1, giao hàng kẹt mãi.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969445
# ================================================================================
# Row 127
# Text : dien thoai đúng như mô tả, giá hợp lý.
# Gold : neutral
# Pred : neutral
# Conf : 0.929152
# ================================================================================
# Row 128
# Text : Đúng với mô tả:oki. Chất liệu:vải nỉ. Màu sắc:xanh than. . Áo nỉ mỏng nhẹ, màu ở ngoài tối hơn trong ảnh.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.705508
# ================================================================================
# Row 129
# Text : Sản phẩm chuot ổn áp 👍, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.969239
# ================================================================================
# Row 130
# Text : Mùi hương của Blue không phải mùi này!Mình tưởng là "dỏm" chỉ khác "xịn" ở chỗ lưu hương nhanh phai,ai dè là trộn nước hoa đểu nồng thiệt là nồng kèm với màu xanh léc,không khéo ố hư luôn áo!Giờ muốn đem cho cũng không dám cho!Hajz
# Gold : very_negative
# Pred : very_negative
# Conf : 0.535565
# ================================================================================
# Row 131
# Text : Hàng giống như mô tả. Đóng gói hàng trong túi zip, không có vỏ hộp. Giao hàng tương đối nhanh. Âm thanh hơi nhỏ.
# Gold : neutral
# Pred : neutral
# Conf : 0.653132
# ================================================================================
# Row 132
# Text : Đúng với mô tả:không đúng. Màu sắc:be. Chất liệu:ct. . Gửi hàng k đúng mẫu chán thật
# Gold : very_negative
# Pred : very_negative
# Conf : 0.970812
# ================================================================================
# Row 133
# Text : CHÊ! DỞM LẮM! KO NÊN MUA ☹️VIDEO BẰNG CHỨNG 🖤🖤. mua từ ngày 11 / 1 /2024 đến 21/1/2024 mà HỎNG rồi ☹️ . Shop chỉnh sẵn giờ rồi ngờ đâu 10 NGÀY HỎNG ☹️ CHƯA NỔI 10 NGÀY ☹️ bằng chứng VIDEO TRÊN 😭😭😭
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969509
# ================================================================================
# Row 134
# Text : chuot bực mình vl, giao hàng lâu.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.968786
# ================================================================================
# Row 135
# Text : "Bọc sách không vừa, dẫn đến ép bị bung, bọc không vừa với khổ bìa nên bị kéo cong. Minh kha that vong."
# Gold : negative
# Pred : negative
# Conf : 0.941574
# ================================================================================
# Row 136
# Text : chuot thảm họa 😱, giao hàng kẹt mãi.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.970097
# ================================================================================
# Row 137
# Text : Tính năng nổi bật là kêu to. Chất lượng sản phẩm đập cái là vỡ. không đúng với mô tả . OK
# Gold : very_negative
# Pred : very_negative
# Conf : 0.961906
# ================================================================================
# Row 138
# Text : Sản phẩm robot hut bui đỉnh cao 🤩, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.968869
# ================================================================================
# Row 139
# Text : siêu mỏng. ko biết ai mua đựơc dày ko chứ mua cái này tốn tiền. ống hút thì bt. còn gậy đúng mô tả nhưng yếu lắm. vặt mấy quả nho nhỏ thôi
# Gold : very_negative
# Pred : very_negative
# Conf : 0.543496
# ================================================================================
# Row 140
# Text : Đúng với mô tả:đặt 2 giao 1. . Bẩn mấy cái trắng
# Gold : very_negative
# Pred : very_negative
# Conf : 0.944326
# ================================================================================
# Row 141
# Text : Có trả hàng dc ko.toàn tiếng tàu.ko dùng dc.hình nền ko như trong giới thiệu.chẳng khác ji 1 chiếc điện thoại đen trắng
# Gold : very_negative
# Pred : very_negative
# Conf : 0.966231
# ================================================================================
# Row 142
# Text : Nếu mua lại ko? Thì ko nên mua lại.
# Gold : negative
# Pred : negative
# Conf : 0.954059
# ================================================================================
# Row 143
# Text : Nước hoa thơm nhưng mà giao hàng đo vo hết rồi biết sao giờ
# Gold : negative
# Pred : negative
# Conf : 0.934874
# ================================================================================
# Row 144
# Text : Mình thấy may anh rep chậm, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.963518
# ================================================================================
# Row 145
# Text : đc
# Gold : neutral
# Pred : positive
# Conf : 0.700770
# ================================================================================
# Row 146
# Text : "Hàng không giống quảng cáo,chân hông chững chắc. Quá tệ"
# Gold : very_negative
# Pred : very_negative
# Conf : 0.970214
# ================================================================================
# Row 147
# Text : Sản phẩm mua về bị lỗi báo shop không phản hồi
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969406
# ================================================================================
# Row 148
# Text : "Đây không phải là lần đầu tiên mình thanh toán Momo nhưng mình rất thất vọng về thái độ của shipper Tiki đối với hàng đã thanh toán. Đầu tiên, shipper gọi mình hỏi có ở nhà k, mình đã bảo mình đang ở nhà và sẽ xuống lầu rồi. Ai dè anh shipper thản nhiên hỏi ""Vậy mình quăng hàng qua hàng rào cho bạn nha?"" Cái gì vậy? Hàng mình dù k phải là hàng dễ bể nhưng cũng k phải là rác mà muốn quăng thì quăng. Mình đã bảo thì có ở nhà và sẽ nhận hàng mà đòi quăng hàng mình là sao. Ảnh cũng ừ ừ cho đã. Sau đó mình xuống nhà thì bất ngờ ảnh đã tự tiện giao hàng của mình cho bà chủ trọ rồi trong khi chưa có sự đồng ý của mình. Nếu ảnh đã muốn làm theo ý của ảnh thì còn gọi cho khách để xác nhận có ở nhà không làm gì. Minh mong Tiki hướng dẫn lại shipper của mình là hàng đã thanh toán trước nhưng k phải là rác, k phải muốn quăng thì quăng và k phải muốn giao hàng của khách cho ai thì giao. Lỡ có vấn đề gì với hàng hoăc mất hàng thì ai chịu trách nhiệm ?"
# Gold : very_negative
# Pred : very_negative
# Conf : 0.871280
# ================================================================================
# Row 149
# Text : Cách viết của tác giả theo mình thấy có hơi rườm rà. Nhưng cuốn sách vẫn đảm bảo mang đến cho bạn những gì nó đã hứa
# Gold : negative
# Pred : negative
# Conf : 0.960677
# ================================================================================
# Row 150
# Text : Chất liệu:tốt
# Gold : very_positive
# Pred : positive
# Conf : 0.593817
# ================================================================================
# Row 151
# Text : Nó giống như điện giật má oi ... Sẽ không mua lại ... Shop nhiệt tình
# Gold : negative
# Pred : negative
# Conf : 0.324662
# ================================================================================
# Row 152
# Text : T đánh giá te, vì đóng gói về nhận thì nó méo nó hết t ngồi bẻ lại mà kh thành hồn =))
# Gold : negative
# Pred : negative
# Conf : 0.685942
# ================================================================================
# Row 153
# Text : "Mới khui, *** nghe được 1 tai"
# Gold : very_negative
# Pred : very_negative
# Conf : 0.962456
# ================================================================================
# Row 154
# Text : Mình thấy chuot rep chậm, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.961802
# ================================================================================
# Row 155
# Text : Chất liệu:vải, mỏng, tệ. Màu sắc:Sai, mua đen lại gửi xanh than😑.. Dính lông vải khác. Quá thật vọng. mn đừng mua nhé!!
# Gold : very_negative
# Pred : very_negative
# Conf : 0.968015
# ================================================================================
# Row 156
# Text : dong ho không nổi bật, giá hợp lý.
# Gold : neutral
# Pred : neutral
# Conf : 0.931737
# ================================================================================
# Row 157
# Text : laptop hỏng ngay lần 1, giao hàng lâu.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969923
# ================================================================================
# Row 158
# Text : Đóng gói kỹ, phù hợp giá tiền
# Gold : positive
# Pred : positive
# Conf : 0.721835
# ================================================================================
# Row 159
# Text : Thật sự mua về bể hết. Shop lm ăn ko uy tín gì
# Gold : very_negative
# Pred : very_negative
# Conf : 0.954966
# ================================================================================
# Row 160
# Text : Tạm được. Nhưng ko giống hoàn toàn so với quảng cáo.
# Gold : neutral
# Pred : negative
# Conf : 0.609121
# ================================================================================
# Row 161
# Text : Đóng gói tốt . Giao hàng nhái .. Trên remote khg có dòng chữ : chunghop. Hàng nhái .
# Gold : very_negative
# Pred : very_negative
# Conf : 0.939938
# ================================================================================
# Row 162
# Text : Máy massage không có hướng dẫn sử dụng nên mò tới mò lui mới biết cách xài, tí nữa tưởng đâu máy hỏng không đó. mn nhấn đồng thời nút on/off và nút "+" thì máy chạy. Tắt mày thì nhấn "-"
# Gold : very_negative
# Pred : very_negative
# Conf : 0.955237
# ================================================================================
# Row 163
# Text : Sản phẩm laptop best choice, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.906983
# ================================================================================
# Row 164
# Text : Sản phẩm laptop đỉnh cao 🤩, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.968088
# ================================================================================
# Row 165
# Text : Đặt màu đen lại gửi màu đỏ. Chất vải bình thường phù hợp với túi tiền. Phom áo rộng
# Gold : neutral
# Pred : neutral
# Conf : 0.880919
# ================================================================================
# Row 166
# Text : Giao hàng nhanh. Nhưng mình mua 10 cái giao thiếu 1 cái, con gái mình . Đếm đi đếm lại vẫn 9 cái
# Gold : very_negative
# Pred : very_negative
# Conf : 0.690115
# ================================================================================
# Row 167
# Text : Mua áo này gửi áo kia, shop 4,9/5 sao mà làm ăn chả ra sao :)
# Gold : very_negative
# Pred : very_negative
# Conf : 0.962351
# ================================================================================
# Row 168
# Text : Màu sắc:trắng. Chất liệu:mỏng. Đúng với mô tả:gửi k đúng mẫu .k tin tưởng đc shop lại làm ăn k có uy tín vậy. . Gửi k đúng mẫu mình đặt . thất vọng
# Gold : very_negative
# Pred : very_negative
# Conf : 0.971685
# ================================================================================
# Row 169
# Text : Sản phẩm đúng hình nhưng chất lượng tạm ổn, do sản phẩm ghi xạc nhanh nhưng thực ra xạc bình thường. Sản phẩm phù hợp với giá tiền
# Gold : neutral
# Pred : neutral
# Conf : 0.610599
# ================================================================================
# Row 170
# Text : Mình thấy man hinh khó chịu vc, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.932474
# ================================================================================
# Row 171
# Text : dùng ốp này ốp lên như kiểu dán màn hình đt bị vào bọt khí ấy…k tương thích. k nên sài
# Gold : negative
# Pred : negative
# Conf : 0.786618
# ================================================================================
# Row 172
# Text : Mình thấy tai nghe tạm bợ, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.964440
# ================================================================================
# Row 173
# Text : Màu sắc:đúng với mô tả. Chất liệu:ko bt. Đúng với mô tả:ko chỉnh được giờ , phút , ngày như trong video
# Gold : negative
# Pred : very_negative
# Conf : 0.923545
# ================================================================================
# Row 174
# Text : Công dụng:dưỡng môi. Mùi hương:có mùi nhựa rất khó chịu
# Gold : very_negative
# Pred : very_negative
# Conf : 0.970238
# ================================================================================
# Row 175
# Text : Màu sắc:đen. Chất liệu:mỏng. Đúng với mô tả:đúng. . Khá mỏng,giá cũng rẻ nên k mong chờ j nhiều,đường chỉ lỗi hơi nhiều.tham khảo thử ha :))
# Gold : positive
# Pred : very_positive
# Conf : 0.753987
# ================================================================================
# Row 176
# Text : Sản phẩm bị lỗi. Đã nhắn tin bảo kiểm tra sản phẩm trước khi giao rồi. Nếu có thể đánh giá 0 sao là đáng giá 0 sao rồi. Chứ ở đó mà 1 sao
# Gold : very_negative
# Pred : very_negative
# Conf : 0.955682
# ================================================================================
# Row 177
# Text : "Dây tai nghe nhìn hơi mong manh, tai nghe cũng tạm ok ạ. Jack cắm hơi lỏng, phải chỉnh tới lui một lúc mới nghe được đủ 2 bên."
# Gold : neutral
# Pred : neutral
# Conf : 0.883112
# ================================================================================
# Row 178
# Text : Hàng giao lâu, đế giày trong ảnh màu đen nhưng ở ngoài lại là màu da. Giày đi khá là cứng
# Gold : very_negative
# Pred : very_negative
# Conf : 0.903453
# ================================================================================
# Row 179
# Text : Bh lần 2, đồng hồ nhanh hết pin (Bh nói đã thay pin mới nhưng mang về vẫn không khá hơn kèm theo báo pin quá nóng. )
# Gold : very_negative
# Pred : very_negative
# Conf : 0.901815
# ================================================================================
# Row 180
# Text : Vỏ thì khá mới mà pha sữa có cặn ở đáy cốc k tan dc ăn sạt như cát
# Gold : negative
# Pred : negative
# Conf : 0.887793
# ================================================================================
# Row 181
# Text : Sản phẩm chuot ngon lành cành đào, dùng khá ok.
# Gold : positive
# Pred : positive
# Conf : 0.927516
# ================================================================================
# Row 182
# Text : Mua lần đầu, chưa xài, hy vọng ổn.. Sau khi gắn vào máy và xài thì ko ổn tí nào nha (15/3/2024).. Do mình bận nên tới nay mới test thử thì thất vọng. Gắn miếng dán vô nó bị đùn ở giữa nên dán vào người ko rung đc, thử 2 miếng rồi vẫn bị đùn như nhau.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.927334
# ================================================================================
# Row 183
# Text : Mình thấy dien thoai fail toàn tập, chất lượng chưa ổn.
# Gold : negative
# Pred : negative
# Conf : 0.854737
# ================================================================================
# Row 184
# Text : Đặt kem đã từng mua giờ giao lại giao loại gel , ko đúng hàng cần đặt hàng
# Gold : very_negative
# Pred : negative
# Conf : 0.627311
# ================================================================================
# Row 185
# Text : KHÔNG NÊN MUA . Đóng gói sơ sài
# Gold : negative
# Pred : negative
# Conf : 0.927459
# ================================================================================
# Row 186
# Text : "Đóng gói ok. Chất lượng OK. Nội dung ko hay lắm"
# Gold : positive
# Pred : positive
# Conf : 0.958266
# ================================================================================
# Row 187
# Text : "không như kỳ vọng, chỉ được mỗi cái quét bàn phím thì tạm được"
# Gold : neutral
# Pred : neutral
# Conf : 0.935333
# ================================================================================
# Row 188
# Text : "mua 4 usb bị 1 cái hư, chat với nhà bán hàng không thấy trả lời, mong ứng dụng mua hàng TIKI đổi lại giùm."
# Gold : very_negative
# Pred : very_negative
# Conf : 0.963106
# ================================================================================
# Row 189
# Text : Dây thì được bảo là silicon nhưng rất cứng, so với dây cũ của mình là silicon thì khác một trời một vực. Giây giống nhựa dẻo hơn là silicon
# Gold : negative
# Pred : negative
# Conf : 0.670353
# ================================================================================
# Row 190
# Text : Hàng đểu
# Gold : very_negative
# Pred : very_negative
# Conf : 0.964769
# ================================================================================
# Row 191
# Text : loa hỏng ngay lần 1, giao hàng kẹt mãi.
# Gold : very_negative
# Pred : very_negative
# Conf : 0.969574
# ================================================================================
# Row 192
# Text : đặt áo này gửi về áo kia nt shop k trl
# Gold : very_negative
# Pred : very_negative
# Conf : 0.659613
# ================================================================================
# Row 193
# Text : "mới nhận hàng, xài thử thấy cũng ok... chưa biết độ bền ra sao..."
# Gold : neutral
# Pred : neutral
# Conf : 0.529148
# ================================================================================
# Row 194
# ...
# Row 463
# Text : Nhận hàng đầy đủ củ sạc tất cả các cổng đều nhận. Sạc thì bình thường không có nhanh như quảng cáo được cái nhiều cổng mức giá vậy cũng hợp lý
# Gold : positive
# Pred : positive
# Conf : 0.488274
# ================================================================================
# Row 464
# Text : Đúng với mô tả:đúng. Chất liệu:nhựa. Màu sắc:đúng màu đã chọn. . Hàng rẻ tiền làm đồ chơi hợp lý. Dùng hết pin không thể thay thế lên cần quảng cáo là hàng dùng 1 lần sẽ hợp lý hơn nữa
# Gold : very_positive
# Pred : very_positive
# Conf : 0.777502
# ================================================================================
# Row 465
# Text : Rất hop vs ng bị đau tay chân phù hợp túi tiền giá rẻ sinh vien
# Gold : very_positive
# Pred : very_positive
# Conf : 0.795889
# ================================================================================
# Row 466
# Text : Đay là chiec thứ 2 mình mua của shop này đh chat luong tot nen mua
# Gold : very_positive
# Pred : very_positive
# Conf : 0.692088
# ================================================================================
# Row 467
# Text : Giao Hàng Nhanh chóng, nhiệt tình, bao bì chắc chắn, cẩn thân, bắt mắt . Chất lượng tạm ổn,
# Gold : very_positive
# Pred : very_positive
# Conf : 0.816212
# ================================================================================
# Row 468
# Text : nhẫn cứng cáp, loại này thì k dễ ra teng đâu, xịn, sáng lấp lánh thật sự. lần đầu mua nhẫn mà thấy vừa xịn vừa rẻ như vậy. nên mua nha mn đừng có phân vân suy nghĩ nhiều quá nhe
# Gold : very_positive
# Pred : very_positive
# Conf : 0.815632
# ================================================================================
# Row 469
# Text : Chất liệu:thun. Màu sắc:xám. Đúng với mô tả:đúng. . Rộng mình thích ôm . Vì mình mặc ở trong nhà hằng ngày
# Gold : very_positive
# Pred : very_positive
# Conf : 0.793799
# ================================================================================
# Row 470
# Text : Nhận hàng nhanh.a shipper thân thiện sẽ ủng hộ nếu có nhu cầu.tks shop nhìu nha.hinh ảnh chỉ mang tính chất minh hoạ
# Gold : very_positive
# Pred : very_positive
# Conf : 0.790087
# ================================================================================
# Row 471
# Text : Đúng với mô tả:ok. Chất liệu:thép. Màu sắc:bạc. . Hàng ok mua đc giá sale rất rẻ, hy vọng pin bền mỗi tội dây hơi rộng phải đi cắt dây
# Gold : very_positive
# Pred : very_positive
# Conf : 0.793086
# ================================================================================
# Row 472
# Text : Các bạn tuổi teen nên dùng nha , giá hợp lý , tốt nha , mk mới dùng 1 lần nên chx bt có hiệu quả lắm không nhưng mk nghe nhìu reviewers bảo ok lắm nha chấm 8/10😘❤️
# Gold : very_positive
# Pred : very_positive
# Conf : 0.788618
# ================================================================================
# Row 473
# Text : Đẹp lắm ạ 🥰 mk đọc đánh giá thấy có ng đánh giá 1⭐ nên hơi lo nhg mà mua về sài đc ạ 😘chụp hình xink lắm mà còn có chơi game nx , chắc mua về chơi cả ngày luôn í 🫰💖.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.787908
# ================================================================================
# Row 474
# Text : Kinh nghiệm sử dụng:cx dc. Hiệu ứng làm đẹp:cx dc. Lợi ích:giúp đẹp hơn đó a nhà moi ng ạ 🥺🌷🫶🧸 với các bạn đi chơi với bọn bn cho e hoi la mã đã
# Gold : very_positive
# Pred : very_positive
# Conf : 0.729892
# ================================================================================
# Row 475
# Text : Màu sắc:trắng. Chất liệu:vải. Đúng với mô tả:đúng. . Áo đẹp mà hơi mỏng ạ . Hình ảnh chỉ mang tính chất minh họa ạ
# Gold : very_positive
# Pred : very_positive
# Conf : 0.796250
# ================================================================================
# Row 476
# Text : Đóng gói cẩn thận, sản phẩm đẹp, sạc siêu nhanh, ship nhanh. Rất hài lòng với cách phục vụ của shop! Votes 5 sao
# Gold : very_positive
# Pred : very_positive
# Conf : 0.823142
# ================================================================================
# Row 477
# Text : Giao hàng nhanh chóng, chất lưởng sản phẩm rất tổt, sẽ tiếp tục ủng họp shop
# Gold : very_positive
# Pred : very_positive
# Conf : 0.820295
# ================================================================================
# Row 478
# Text : Tôi hài lòng với sản phẩm mình chọn mua. Sp được giao đúng giờ hẹn. Nồi nhìn sang nhưng mỏng và nhẹ như giá tiền. Tôi chưa dùng nên chưa biết chất lượng thế nào. Hy vọng là bền tí cho đỡ chi tiêu mua sắm mới
# Gold : very_positive
# Pred : very_positive
# Conf : 0.476177
# ================================================================================
# Row 479
# Text : Đã nhận hàng nhưng không biết mùi hương sao . Ảnh và video mang tính chất nhận xu
# Gold : very_positive
# Pred : very_positive
# Conf : 0.717347
# ================================================================================
# Row 480
# Text : Âm thanh nghe rõ, mẫu giống trong hình, có điều giao hơi lâu
# Gold : neutral
# Pred : positive
# Conf : 0.708675
# ================================================================================
# Row 481
# Text : Hàng giống như mô tả cắm vào máy có chạy tuy nhiên chưa biết chất lượng vì mới dùng giao hàng nhanh đóng gói cẩn thận
# Gold : positive
# Pred : positive
# Conf : 0.775644
# ================================================================================
# Row 482
# Text : Đã nhận đủ số lượng, chất lượng thế nào phải đợi thêm thời gian mới đánh giá được. Dù sao cũng cảm ơn shop.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.676937
# ================================================================================
# Row 483
# Text : Tặng kèm 1
# Gold : very_positive
# Pred : neutral
# Conf : 0.705225
# ================================================================================
# Row 484
# Text : Mình mua đúng đợt giảm giá, sản phẩm được mình bỏ vào giỏ hàng bấy lâu nay giờ cũng cầm được trên tay rồi. sản phẩm xài tạm được thôi
# Gold : neutral
# Pred : positive
# Conf : 0.578002
# ================================================================================
# Row 485
# Text : Với giá tiền này như ri là được rồi .hàng dùng rất oki .mẫu đẹp .giao hàng nhanh .lần sau sẽ ủng hộ
# Gold : very_positive
# Pred : very_positive
# Conf : 0.812952
# ================================================================================
# Row 486
# Text : Hàng dùng rất ok , chất lượng sản phẩm tốt, đã mua và thật sự yên tâm về chất lượng mẫu mã màu sắc và cách sử dụng. giao hàng nhanh, cảm ơn shop rất nhiêu
# Gold : very_positive
# Pred : very_positive
# Conf : 0.819703
# ================================================================================
# Row 487
# Text : Lấn cấn vì em rể chăm sóc thư ký quá chu đáo, chị vợ đánh hơi thấy mùi ngoại tình
# Gold : very_positive
# Pred : very_positive
# Conf : 0.782310
# ================================================================================
# Row 488
# Text : Sản phẩm đúng như mô tả chất liệu nhựa hơi mỏng sử dụng thuận tiện
# Gold : very_positive
# Pred : positive
# Conf : 0.821267
# ================================================================================
# Row 489
# Text : Trước đi da liễu, da mình nhạy cảm bác sĩ có cho dùng loại này rồi. Hương thơm nhẹ. Tạo bọt nhiều. Rửa khá thích. Phù hợp với da nhạy cảm vì ko có thành phần kích ứng. Mua đợt 10/10 còn được tặng 1 hộp bông tẩy trang nữa ạ. Vote shop 5 sao
# Gold : very_positive
# Pred : very_positive
# Conf : 0.816618
# ================================================================================
# Row 490
# Text : Giá thành rẻ nữa mà vô cùng chất lượng nhà ,nên mua nha 😉
# Gold : very_positive
# Pred : very_positive
# Conf : 0.777190
# ================================================================================
# Row 491
# Text : Sản phẩm phù hợp với giá tiền. Chưa dung nên k biết thế nào. Sẽ ủng hộ tiếp tục nếu dùng tốt nhé
# Gold : very_positive
# Pred : very_positive
# Conf : 0.717432
# ================================================================================
# Row 492
# Text : May mà mua cái có cả massage mũi cái đấy nó to nên dùng massage đầu luôn tại vì nó thoải mái chứ dùg mấy răng kia chỉ để chải đầu thôi chứ để kích mọc tóc thì hơi đau😶
# Gold : very_positive
# Pred : very_positive
# Conf : 0.475184
# ================================================================================
# Row 493
# Text : Cá nhân mình chấmmm 8/10 chụp đẹp khá nét , màu ổn nhma lâu lâu bị mách hết pinn ??? , nói chung cũng ổn so vs tầm giá màu khá đẹp , hìnnnh này chụp từ máy ảnnhh
# Gold : very_positive
# Pred : very_positive
# Conf : 0.790868
# ================================================================================
# Row 494
# Text : Chx sử dụng nên ko bt như nào, chỉ dám đánh giá 4* thôi . Shipper giao hàng siêu nhanh ,ms đặt sáng hôm qua mà trưa nay đã nhận đc r .
# Gold : very_positive
# Pred : very_positive
# Conf : 0.748230
# ================================================================================
# Row 495
# Text : Loa như vầy nghe nghe cũng ổn, tuy k to nhưng vẫn ok
# Gold : positive
# Pred : positive
# Conf : 0.946416
# ================================================================================
# Row 496
# Text : áo không giống màu trên ảnh lắm nhưng với giá này thì chất lượng khá ok ạ
# Gold : very_positive
# Pred : very_positive
# Conf : 0.749650
# ================================================================================
# Row 497
# Text : Tạm thời thấy chỉ kết nối bờ lu tút,nghe nhạc,to,khỏe,loa size nhỏ gọn,đóng gói giao hàng tốt
# Gold : very_positive
# Pred : very_positive
# Conf : 0.685656
# ================================================================================
# Row 498
# Text : Nhận nhưng chưa dùng nên k biết chất lượng. Nhưng giá hợp lý.lần sau ủng hộ shop
# Gold : very_positive
# Pred : very_positive
# Conf : 0.791842
# ================================================================================
# Row 499
# Text : Chất liệu:OK. Màu sắc:đen size a. Đúng với mô tả:ngon
# Gold : very_positive
# Pred : very_positive
# Conf : 0.805948
# ================================================================================
# Row 500
# Text : nhìn lọ mini cx dth sẽ ủng hộ shop lần tới
# Gold : very_positive
# Pred : very_positive
# Conf : 0.792085
# ================================================================================
# Row 501
# Text : Dầu thơm cay nhẹ mùi giống như ống hít á, k bik có hiệu quả trị viêm xoang thật k nhưng sức cũng đỡ nhức đầu mong là sẽ trị dc viêm xoang kkk nên mua giá rẻ
# Gold : very_positive
# Pred : very_positive
# Conf : 0.790406
# ================================================================================
# Row 502
# Text : Hàng cx ổn sài tốt giá cững vừa phải, hàng giao rất nhanh ms đặt hôm qua mà nay giao ròi💗
# Gold : very_positive
# Pred : very_positive
# Conf : 0.805200
# ================================================================================
# Row 503
# Text : Dụng cụ gỗ mát xa chân nhỏ gọn bằng gỗ, dùng thử thấy cũng tiện lợi, lăn chân dễ chịu, đóng gói cẩn thận
# Gold : very_positive
# Pred : very_positive
# Conf : 0.742129
# ================================================================================
# Row 504
# Text : Nay mình nhận hàng, sản phẩm của shop có bao bì mắt mắt, khẩu trang không mùi, đeo vào cảm giác dễ chịu, nên mua nhé mọi người.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.813249
# ================================================================================
# Row 505
# Text : Màu sắc:đen. Đúng với mô tả:giống. Chất liệu:ko bt. . Giá rẻ không biết có bền không nhưng nhìn qua rất OK và ko bt sản phẩm có chống nước đc ko và chỉ xem đc giờ ko xem đc ngày
# Gold : very_positive
# Pred : very_positive
# Conf : 0.506865
# ================================================================================
# Row 506
# Text : Rất chi là ok luôn một cọng dây sạc vậy chị có vài chục nghìn thôi mà có thể ngắt nguồn điện khá là rẻ shop còn rất là tận tình với mình nữa ok 5 sao hết chỗ chê
# Gold : very_positive
# Pred : very_positive
# Conf : 0.809080
# ================================================================================
# Row 507
# Text : Chưa sử dụng chua biết thế nào mà với giá thành này được mẫu ma sản phẩm đẹp ok
# Gold : very_positive
# Pred : very_positive
# Conf : 0.639129
# ================================================================================
# Row 508
# Text : Ok dây khá là tốt được quấn vải dù nên rất chắc ghị không đức mà không biết dùng bền không trong bao lâu sẽ hư với chính sách bảo hành có ko nữa thì mới cho 5 sao được bây giờ tặng tạm thời 4 sao nha. Cảm ơn shop và bác tài xế shipper rất nhiều.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.743823
# ================================================================================
# Row 509
# Text : Đúng với mô tả:đúng. Màu sắc:xanh đen. Chất liệu:vải. . Áo đúng màu,đẹp,vải bình thg,không dày cũng không mỏng,bạn nào muốn mặc rộng 1 xíu thì tăng lệch 1 size nha,mình cao 1m65 mặc qua mông size xl2 là vừa.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.806610
# ================================================================================
# Row 510
# Text : Nệm dày, nằm êm rất thoải mái 🫶 Cũng đắn đo lắm, coi mấy shop khác thấy review nhận về nệm mỏng, mà shop này chất lượng ghê 😍
# Gold : very_positive
# Pred : very_positive
# Conf : 0.818298
# ================================================================================
# Row 511
# Text : Màu sắc:hồng. Chất liệu:không biết. Đúng với mô tả:đẹp. . Rất đẹp và ưng đúng với mô tả cảm thấy rất hài lòng và lần sau thể quay lại ủng hộ shop tiếp
# Gold : very_positive
# Pred : very_positive
# Conf : 0.813143
# ================================================================================
# Row 512
# Text : Son đúng mẫu, mùi kẹo ngọt. Ban đầu mình tưởng màu nó cũng đậm lắm nhma khi giao về thì cũng chỉ đỏ pha chút hồng thoi.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.778694
# ================================================================================
# Row 513
# Text : Vòng đẹp , dây nhỏ dễ đứt , 5 hôm là hàng về
# Gold : very_positive
# Pred : very_positive
# Conf : 0.792977
# ================================================================================
# Row 514
# Text : Remix loa zè nhé mn, giao diện ok
# Gold : very_positive
# Pred : very_positive
# Conf : 0.808074
# ================================================================================
# Row 515
# Text : giao nhanh, gói hàng cẩn thận, nhìn ban đầu thấy đẹp, oke. Chưa thử lên máy nên chưa biết thế nào nữa
# Gold : very_positive
# Pred : very_positive
# Conf : 0.771957
# ================================================================================
# Row 516
# Text : Thời gian giao hàng nhanh, gói hàng cần thận, chưa dùng nên chưa thể đánh giá được
# Gold : positive
# Pred : neutral
# Conf : 0.717511
# ================================================================================
# Row 517
# Text : Áo khoác đúng như giới thiệu .mình thun mát mẻ dễ chịu ..kiểu cách phù hợp với mọi lứa tuổi ..trung niên cũng rất ok ..
# Gold : very_positive
# Pred : very_positive
# Conf : 0.804502
# ================================================================================
# Row 518
# Text : Nhỏ hơn mình nghĩ chút , shop chăm sóc khách hàng khá oke , nói chung dùng cũng được.
# Gold : very_positive
# Pred : very_positive
# Conf : 0.615394
# ================================================================================
# Row 519
# Text : Chui cắm lỏng lẻo, giá rẻ nhưng không nghĩ dây nó tệ vậy
# Gold : negative
# Pred : negative
# Conf : 0.771308
# ================================================================================
# Row 520
# Text : mình nhận được đủ 10 gói nha còn đủ 100 cái kh thì mình chả biết , dùng oke
# Gold : positive
# Pred : positive
# Conf : 0.422684
# ================================================================================
# Row 521
# Text : Bự nha nằm lăn ko hết nói chung mua giá rẻ hợp lí vậy thì quá ok luôn rồi
# Gold : very_positive
# Pred : very_positive
# Conf : 0.814545
#
# ################################################################################
# Done. Samples: 521
# Accuracy: 0.9117 (475/521)
#
# Gold label counts: Counter({'very_negative': 157, 'very_positive': 141, 'negative': 87, 'positive': 72, 'neutral': 64})
# Pred label counts: Counter({'very_negative': 161, 'very_positive': 140, 'positive': 81, 'negative': 78, 'neutral': 61})

# %%
import csv
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
)

CSV_PATH = Path("../data/test/test.csv")


def predict_dataset(csv_path=CSV_PATH, max_rows=None):
    """
    Đọc CSV (text,label), dùng predict_one() để dự đoán.
    Trả về: y_true, y_pred (danh sách label string).
    """
    y_true, y_pred = [], []

    with csv_path.open("r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for i, row in enumerate(reader):
            if max_rows is not None and i >= max_rows:
                break

            text = row["text"]
            gold = row["label"].strip()

            pred_lbl, conf, probs = predict_one(text)

            y_true.append(gold)
            y_pred.append(pred_lbl)

    return y_true, y_pred


# ==== Chạy dự đoán toàn bộ file ====
y_true, y_pred = predict_dataset()

# ==== Accuracy tổng ====
acc = accuracy_score(y_true, y_pred)
print(f"Accuracy: {acc:.4f}  ({sum(np.array(y_true) == np.array(y_pred))}/{len(y_true)})")

# ==== Precision, Recall, F1 (theo từng lớp + macro/weighted) ====
print("\nClassification report:")
print(
    classification_report(
        y_true,
        y_pred,
        labels=LABELS_5,
        target_names=LABELS_5,
        digits=4,
        zero_division=0,
    )
)

prec, rec, f1, support = precision_recall_fscore_support(
    y_true,
    y_pred,
    labels=LABELS_5,
    zero_division=0,
)
macro_prec = prec.mean()
macro_rec = rec.mean()
macro_f1 = f1.mean()

print("Macro precision:", f"{macro_prec:.4f}")
print("Macro recall   :", f"{macro_rec:.4f}")
print("Macro F1       :", f"{macro_f1:.4f}")

# ==== Confusion Matrix (đếm) ====
cm = confusion_matrix(y_true, y_pred, labels=LABELS_5)

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(cm, interpolation="nearest", cmap="Blues")
plt.colorbar(im, ax=ax)
ax.set_xticks(np.arange(len(LABELS_5)))
ax.set_yticks(np.arange(len(LABELS_5)))
ax.set_xticklabels(LABELS_5, rotation=45, ha="right")
ax.set_yticklabels(LABELS_5)
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_title("Confusion Matrix (Counts)")
max_val = cm.max() if cm.size > 0 else 0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        v = cm[i, j]
        text_color = "white" if v > max_val * 0.6 else "black"
        ax.text(j, i, v, ha="center", va="center", color=text_color)
plt.tight_layout()
plt.show()

# ==== Confusion Matrix (normalized theo hàng) ====
cm_norm = cm.astype("float")
row_sums = cm_norm.sum(axis=1, keepdims=True)
cm_norm = np.divide(cm_norm, row_sums, out=np.zeros_like(cm_norm), where=row_sums != 0)

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(cm_norm, interpolation="nearest", cmap="Blues")
plt.colorbar(im, ax=ax)
ax.set_xticks(np.arange(len(LABELS_5)))
ax.set_yticks(np.arange(len(LABELS_5)))
ax.set_xticklabels(LABELS_5, rotation=45, ha="right")
ax.set_yticklabels(LABELS_5)
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_title("Confusion Matrix (Normalized)")
max_val_norm = cm_norm.max() if cm_norm.size > 0 else 0
for i in range(cm_norm.shape[0]):
    for j in range(cm_norm.shape[1]):
        v = cm_norm[i, j]
        text_color = "white" if v > max_val_norm * 0.6 else "black"
        ax.text(j, i, f"{v:.2f}", ha="center", va="center", color=text_color)
plt.tight_layout()
plt.show()
# Out:
# [INFO] Auto-restore diacritics → ""nap nhua de van bulong thay doi khoang cach cua giá độ moi van vao de giu dien thoai. da bi rot ra nhu hình""
# [INFO] Auto-restore diacritics → "ngon"
# Accuracy: 0.9117  (475/521)
#
# Classification report:
#                precision    recall  f1-score   support
#
# very_negative     0.9441    0.9682    0.9560       157
#      negative     0.9103    0.8161    0.8606        87
#       neutral     0.8525    0.8125    0.8320        64
#      positive     0.8025    0.9028    0.8497        72
# very_positive     0.9643    0.9574    0.9609       141
#
#      accuracy                         0.9117       521
#     macro avg     0.8947    0.8914    0.8918       521
#  weighted avg     0.9131    0.9117    0.9115       521
#
# Macro precision: 0.8947
# Macro recall   : 0.8914
# Macro F1       : 0.8918

# %%
import time
import torch
from transformers import AutoModelForSequenceClassification

# Câu test cố định để đo thời gian
TEST_TEXT = "Mình thấy chất lượng sản phẩm bình thường, không tốt lắm cũng không tệ."

N = 500  # số lần lặp


# ================== ĐO THỜI GIAN TRÊN GPU (NẾU CÓ) ==================
if device.type == "cuda":
    # warm-up GPU với hàm predict_one hiện tại
    _ = predict_one(TEST_TEXT)
    torch.cuda.synchronize()

    t0 = time.time()
    for _ in range(N):
        _ = predict_one(TEST_TEXT)
    torch.cuda.synchronize()
    t1 = time.time()

    total_time_gpu = t1 - t0
    avg_time_gpu = total_time_gpu / N

    pred_lbl_gpu, conf_gpu, _ = predict_one(TEST_TEXT)

    print("===== GPU inference (predict_one hiện tại) =====")
    print("Text test      :", TEST_TEXT)
    print("Pred label     :", pred_lbl_gpu)
    print("Confidence     :", f"{conf_gpu:.4f}")
    print(f"Device         : {device}")
    print(f"Số lần lặp     : {N}")
    print(f"Tổng thời gian : {total_time_gpu:.4f} s")
    print(f"Thời gian 1 câu: {avg_time_gpu*1000:.2f} ms\n")
else:
    print("Không có GPU / device không phải 'cuda' → bỏ qua đo GPU.\n")


# ================== ĐO THỜI GIAN TRÊN CPU (MODEL RIÊNG) ==================
# Tạo model CPU riêng, không đụng vào model đang dùng cho predict_one
# device_cpu = torch.device("cpu")

# load_kwargs_cpu = dict(torch_dtype=torch.float32, low_cpu_mem_usage=True,
#                        device_map={"": "cpu"})
# mdl_cpu = AutoModelForSequenceClassification.from_pretrained(
#     MODEL_DIR,
#     **load_kwargs_cpu
# ).to(device_cpu).eval()

# def predict_one_cpu(text: str):
#     """Infer 1 câu trên CPU, dùng cùng pipeline preprocess như GPU."""
#     s = preprocess_text(text)

#     with torch.inference_mode():
#         enc = tok([s], truncation=True, padding=True,
#                   max_length=MAX_LEN, return_tensors="pt")
#         enc = {k: v.to(device_cpu) for k, v in enc.items()}
#         logits = mdl_cpu(**enc).logits
#         logits = logits.detach().cpu().numpy()[0]

#     if NEUTRAL_PENALTY != 0.0:
#         logits[2] += NEUTRAL_PENALTY  # 'neutral' index 2

#     probs = softmax_np(logits)
#     pred_id = int(probs.argmax())
#     pred_lbl = ID2LBL[pred_id]
#     return pred_lbl, float(probs[pred_id]), probs

# # warm-up CPU
# _ = predict_one_cpu(TEST_TEXT)

# t0 = time.time()
# for _ in range(N):
#     _ = predict_one_cpu(TEST_TEXT)
# t1 = time.time()

# total_time_cpu = t1 - t0
# avg_time_cpu = total_time_cpu / N

# pred_lbl_cpu, conf_cpu, _ = predict_one_cpu(TEST_TEXT)

# print("===== CPU inference (model riêng trên CPU) =====")
# print("Text test      :", TEST_TEXT)
# print("Pred label     :", pred_lbl_cpu)
# print("Confidence     :", f"{conf_cpu:.4f}")
# print(f"Device         : {device_cpu}")
# print(f"Số lần lặp     : {N}")
# print(f"Tổng thời gian : {total_time_cpu:.4f} s")
# print(f"Thời gian 1 câu: {avg_time_cpu*1000:.2f} ms")
# Out:
# Không có GPU / device không phải 'cuda' → bỏ qua đo GPU.

# %%
import csv
from pathlib import Path

INPUT_CSV  = Path("../data/test/test.csv")
OUTPUT_CSV = Path("../data/test/test_with_pred.csv")

rows_out = []

with INPUT_CSV.open("r", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    fieldnames = reader.fieldnames + ["pred_label", "pred_conf"]

    for i, row in enumerate(reader):
        pred_lbl, conf, probs = predict_one(row["text"])
        row["pred_label"] = pred_lbl
        row["pred_conf"]  = f"{conf:.6f}"
        rows_out.append(row)

        if (i + 1) % 100 == 0:
            print(f"  Processed {i + 1} rows...")

with OUTPUT_CSV.open("w", encoding="utf-8", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(rows_out)

total   = len(rows_out)
correct = sum(r["label"].strip() == r["pred_label"] for r in rows_out)
print(f"\nDone. {total} rows → saved to: {OUTPUT_CSV.resolve()}")
print(f"Accuracy: {correct/total:.4f} ({correct}/{total})")
# Out:
#   Processed 100 rows...
# [INFO] Auto-restore diacritics → ""nap nhua de van bulong thay doi khoang cach cua giá độ moi van vao de giu dien thoai. da bi rot ra nhu hình""
#   Processed 200 rows...
#   Processed 300 rows...
#   Processed 400 rows...
# [INFO] Auto-restore diacritics → "ngon"
#   Processed 500 rows...
#
# Done. 521 rows → saved to: D:\HK252\TTNT\nlp_nckh\data\test\test_with_pred.csv
# Accuracy: 0.9117 (475/521)
